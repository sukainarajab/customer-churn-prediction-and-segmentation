# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel("Telco_customer_churn.xlsx")
df
# Out:
#       CustomerID  Count        Country       State          City  Zip Code  \
# 0     3668-QPYBK      1  United States  California   Los Angeles     90003
# 1     9237-HQITU      1  United States  California   Los Angeles     90005
# 2     9305-CDSKC      1  United States  California   Los Angeles     90006
# 3     7892-POOKP      1  United States  California   Los Angeles     90010
# 4     0280-XJGEX      1  United States  California   Los Angeles     90015
# ...          ...    ...            ...         ...           ...       ...
# 7038  2569-WGERO      1  United States  California       Landers     92285
# 7039  6840-RESVB      1  United States  California      Adelanto     92301
# 7040  2234-XADUH      1  United States  California         Amboy     92304
# 7041  4801-JZAZL      1  United States  California  Angelus Oaks     92305
# 7042  3186-AJIEK      1  United States  California  Apple Valley     92308
#
#                     Lat Long   Latitude   Longitude  Gender  ...  \
# 0     33.964131, -118.272783  33.964131 -118.272783    Male  ...
# 1      34.059281, -118.30742  34.059281 -118.307420  Female  ...
# 2     34.048013, -118.293953  34.048013 -118.293953  Female  ...
# 3     34.062125, -118.315709  34.062125 -118.315709  Female  ...
# 4     34.039224, -118.266293  34.039224 -118.266293    Male  ...
# ...                      ...        ...         ...     ...  ...
# 7038  34.341737, -116.539416  34.341737 -116.539416  Female  ...
# 7039  34.667815, -117.536183  34.667815 -117.536183    Male  ...
# 7040  34.559882, -115.637164  34.559882 -115.637164  Female  ...
# 7041     34.1678, -116.86433  34.167800 -116.864330  Female  ...
# 7042  34.424926, -117.184503  34.424926 -117.184503    Male  ...
#
#             Contract Paperless Billing             Payment Method  \
# 0     Month-to-month               Yes               Mailed check
# 1     Month-to-month               Yes           Electronic check
# 2     Month-to-month               Yes           Electronic check
# 3     Month-to-month               Yes           Electronic check
# 4     Month-to-month               Yes  Bank transfer (automatic)
# ...              ...               ...                        ...
# 7038        Two year               Yes  Bank transfer (automatic)
# 7039        One year               Yes               Mailed check
# 7040        One year               Yes    Credit card (automatic)
# 7041  Month-to-month               Yes           Electronic check
# 7042        Two year               Yes  Bank transfer (automatic)
#
#       Monthly Charges Total Charges Churn Label Churn Value Churn Score  CLTV  \
# 0               53.85        108.15         Yes           1          86  3239
# 1               70.70        151.65         Yes           1          67  2701
# 2               99.65         820.5         Yes           1          86  5372
# 3              104.80       3046.05         Yes           1          84  5003
# 4              103.70        5036.3         Yes           1          89  5340
# ...               ...           ...         ...         ...         ...   ...
# 7038            21.15        1419.4          No           0          45  5306
# 7039            84.80        1990.5          No           0          59  2140
# 7040           103.20        7362.9          No           0          71  5560
# 7041            29.60        346.45          No           0          59  2793
# 7042           105.65        6844.5          No           0          38  5097
#
#                        Churn Reason
# 0      Competitor made better offer
# 1                             Moved
# 2                             Moved
# 3                             Moved
# 4     Competitor had better devices
# ...                             ...
# 7038                            NaN
# 7039                            NaN
# 7040                            NaN
# 7041                            NaN
# 7042                            NaN
#
# [7043 rows x 33 columns]

# %%
df.shape
# Out:
# (7043, 33)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
#  16  Internet Service   7043 non-null   object
#  17  Online Security    7043 non-null   object
#  18  Online Backup      7043 non-null   object
#  19  Device Protection  7043 non-null   object
#  20  Tech Support       7043 non-null   object
#  21  Streaming TV       7043 non-null   object
#  22  Streaming Movies   7043 non-null   object
#  23  Contract           7043 non-null   object
#  24  Paperless Billing  7043 non-null   object
#  25  Payment Method     7043 non-null   object
#  26  Monthly Charges    7043 non-null   float64
#  27  Total Charges      7043 non-null   object
#  28  Churn Label        7043 non-null   object
#  29  Churn Value        7043 non-null   int64
#  30  Churn Score        7043 non-null   int64
#  31  CLTV               7043 non-null   int64
#  32  Churn Reason       1869 non-null   object
# dtypes: float64(3), int64(6), object(24)
# memory usage: 1.8+ MB

# %%
df['Churn Label'].value_counts()
# Out:
# Churn Label
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Tenure Months'],bins=30,kde=True)
plt.title('Distribution of Tenure Months vs no of customer')
plt.xlabel('Tenure Months')
plt.ylabel('Customer count')
plt.show()

# %%
df['Tenure Months'].min()
# Out:
# 0

# %%
df['Tenure Months'].max()
# Out:
# 72

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='Churn Label',y='Tenure Months',data=df)
plt.title('Churn vs Tenure Months')
plt.xlabel('Churn Label')
plt.ylabel('Tenure Months')
plt.show()

# %%
df['Churn Label'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Monthly Charges'],bins=30,kde=True)
plt.title('Distribution of monthly charges vs no of customer')
plt.xlabel('Monthly Charges')
plt.ylabel('Customer count')
plt.show()

# %%
df['Monthly Charges'].max()
# Out:
# 118.75

# %%
df['Monthly Charges'].min()
# Out:
# 18.25

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='Churn Label',y='Monthly Charges',data=df)
plt.title('Churn vs Monthly Charges')
plt.xlabel('Churn Label')
plt.ylabel('Monthly Charges')
plt.show()

# %%
df[df['Churn Label']=='Yes']['Monthly Charges'].quantile([0.25,0.5,0.75])
# Out:
# 0.25    56.15
# 0.50    79.65
# 0.75    94.20
# Name: Monthly Charges, dtype: float64

# %%
df[df['Churn Label']=='No']['Monthly Charges'].quantile([0.25,0.5,0.75])
# Out:
# 0.25    25.100
# 0.50    64.425
# 0.75    88.400
# Name: Monthly Charges, dtype: float64

# %%
df['Monthly Charges'].describe()
# Out:
# count    7043.000000
# mean       64.761692
# std        30.090047
# min        18.250000
# 25%        35.500000
# 50%        70.350000
# 75%        89.850000
# max       118.750000
# Name: Monthly Charges, dtype: float64

# %%
df['Monthly Charges'].quantile([0.25,0.5,0.75])
# Out:
# 0.25    35.50
# 0.50    70.35
# 0.75    89.85
# Name: Monthly Charges, dtype: float64

# %%
df['Contract'].unique()
# Out:
# array(['Month-to-month', 'Two year', 'One year'], dtype=object)

# %%
df['Contract'].value_counts()
# Out:
# Contract
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Contract',hue='Churn Label',data=df)
plt.title('Contract vs count')
plt.xlabel('Contract')
plt.ylabel('Count')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
#  16  Internet Service   7043 non-null   object
#  17  Online Security    7043 non-null   object
#  18  Online Backup      7043 non-null   object
#  19  Device Protection  7043 non-null   object
#  20  Tech Support       7043 non-null   object
#  21  Streaming TV       7043 non-null   object
#  22  Streaming Movies   7043 non-null   object
#  23  Contract           7043 non-null   object
#  24  Paperless Billing  7043 non-null   object
#  25  Payment Method     7043 non-null   object
#  26  Monthly Charges    7043 non-null   float64
#  27  Total Charges      7043 non-null   object
#  28  Churn Label        7043 non-null   object
#  29  Churn Value        7043 non-null   int64
#  30  Churn Score        7043 non-null   int64
#  31  CLTV               7043 non-null   int64
#  32  Churn Reason       1869 non-null   object
# dtypes: float64(3), int64(6), object(24)
# memory usage: 1.8+ MB

# %%
df['Internet Service'].unique()
# Out:
# array(['DSL', 'Fiber optic', 'No'], dtype=object)

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Internet Service',hue='Churn Label',data=df)
plt.title('Internet Service vs count')
plt.xlabel('Internet Service')
plt.ylabel('Count')
plt.show()

# %%
df['Payment Method'].unique()
# Out:
# array(['Mailed check', 'Electronic check', 'Bank transfer (automatic)',
#        'Credit card (automatic)'], dtype=object)

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Payment Method',hue='Churn Label',data=df)
plt.title('Payment Method vs count')
plt.xlabel('Payment Method')
plt.ylabel('Count')
plt.show()

# %%
df['Tech Support'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Tech Support',hue='Churn Label',data=df)
plt.title('Tech Support vs count')
plt.xlabel('Tech Support')
plt.ylabel('Count')
plt.show()

# %%
avg_tenure=df.groupby('Churn Label')['Tenure Months'].mean()
avg_tenure
# Out:
# Churn Label
# No     37.569965
# Yes    17.979133
# Name: Tenure Months, dtype: float64

# %%
numerical_cols=['Tenure Months','Monthly Charges','Churn Value','CLTV']
correlation_matrix=df[numerical_cols].corr()

# %%
correlation_matrix
# Out:
#                  Tenure Months  Monthly Charges  Churn Value      CLTV
# Tenure Months         1.000000         0.247900    -0.352229  0.396406
# Monthly Charges       0.247900         1.000000     0.193356  0.098693
# Churn Value          -0.352229         0.193356     1.000000 -0.127463
# CLTV                  0.396406         0.098693    -0.127463  1.000000

# %%
import pandas as pd
contract_churn= pd.crosstab(df['Contract'],df['Churn Label'],normalize='index')
contract_churn
# Out:
# Churn Label           No       Yes
# Contract
# Month-to-month  0.572903  0.427097
# One year        0.887305  0.112695
# Two year        0.971681  0.028319

# %% [markdown]
# Data Cleaning

# %%
 df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
#  16  Internet Service   7043 non-null   object
#  17  Online Security    7043 non-null   object
#  18  Online Backup      7043 non-null   object
#  19  Device Protection  7043 non-null   object
#  20  Tech Support       7043 non-null   object
#  21  Streaming TV       7043 non-null   object
#  22  Streaming Movies   7043 non-null   object
#  23  Contract           7043 non-null   object
#  24  Paperless Billing  7043 non-null   object
#  25  Payment Method     7043 non-null   object
#  26  Monthly Charges    7043 non-null   float64
#  27  Total Charges      7043 non-null   object
#  28  Churn Label        7043 non-null   object
#  29  Churn Value        7043 non-null   int64
#  30  Churn Score        7043 non-null   int64
#  31  CLTV               7043 non-null   int64
#  32  Churn Reason       1869 non-null   object
# dtypes: float64(3), int64(6), object(24)
# memory usage: 1.8+ MB

# %%
df['Total Charges']
# Out:
# 0        108.15
# 1        151.65
# 2         820.5
# 3       3046.05
# 4        5036.3
#          ...
# 7038     1419.4
# 7039     1990.5
# 7040     7362.9
# 7041     346.45
# 7042     6844.5
# Name: Total Charges, Length: 7043, dtype: object

# %%
df['Total Charges']=pd.to_numeric(df['Total Charges'],errors='coerce')
df['Total Charges']
# Out:
# 0        108.15
# 1        151.65
# 2        820.50
# 3       3046.05
# 4       5036.30
#          ...
# 7038    1419.40
# 7039    1990.50
# 7040    7362.90
# 7041     346.45
# 7042    6844.50
# Name: Total Charges, Length: 7043, dtype: float64

# %%
drop_columns=['CustomerID','Count','Country','State','City','Zip Code','Lat Long','Latitude','Longitude','Churn Label','Churn Score','CLTV','Churn Reason']

# %%
df = df.drop(columns=drop_columns)

# %%
df.isnull().sum()
# Out:
# Gender                0
# Senior Citizen        0
# Partner               0
# Dependents            0
# Tenure Months         0
# Phone Service         0
# Multiple Lines        0
# Internet Service      0
# Online Security       0
# Online Backup         0
# Device Protection     0
# Tech Support          0
# Streaming TV          0
# Streaming Movies      0
# Contract              0
# Paperless Billing     0
# Payment Method        0
# Monthly Charges       0
# Total Charges        11
# Churn Value           0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Gender               0
# Senior Citizen       0
# Partner              0
# Dependents           0
# Tenure Months        0
# Phone Service        0
# Multiple Lines       0
# Internet Service     0
# Online Security      0
# Online Backup        0
# Device Protection    0
# Tech Support         0
# Streaming TV         0
# Streaming Movies     0
# Contract             0
# Paperless Billing    0
# Payment Method       0
# Monthly Charges      0
# Total Charges        0
# Churn Value          0
# dtype: int64

# %%
df_encoded=pd.get_dummies(df,drop_first=True)

# %%
df_encoded.shape
# Out:
# (7032, 31)

# %%
df.dtypes
# Out:
# Gender                object
# Senior Citizen        object
# Partner               object
# Dependents            object
# Tenure Months          int64
# Phone Service         object
# Multiple Lines        object
# Internet Service      object
# Online Security       object
# Online Backup         object
# Device Protection     object
# Tech Support          object
# Streaming TV          object
# Streaming Movies      object
# Contract              object
# Paperless Billing     object
# Payment Method        object
# Monthly Charges      float64
# Total Charges        float64
# Churn Value            int64
# dtype: object

# %%
df_encoded
# Out:
#       Tenure Months  Monthly Charges  Total Charges  Churn Value  Gender_Male  \
# 0                 2            53.85         108.15            1         True
# 1                 2            70.70         151.65            1        False
# 2                 8            99.65         820.50            1        False
# 3                28           104.80        3046.05            1        False
# 4                49           103.70        5036.30            1         True
# ...             ...              ...            ...          ...          ...
# 7038             72            21.15        1419.40            0        False
# 7039             24            84.80        1990.50            0         True
# 7040             72           103.20        7362.90            0        False
# 7041             11            29.60         346.45            0        False
# 7042             66           105.65        6844.50            0         True
#
#       Senior Citizen_Yes  Partner_Yes  Dependents_Yes  Phone Service_Yes  \
# 0                  False        False           False               True
# 1                  False        False            True               True
# 2                  False        False            True               True
# 3                  False         True            True               True
# 4                  False        False            True               True
# ...                  ...          ...             ...                ...
# 7038               False        False           False               True
# 7039               False         True            True               True
# 7040               False         True            True               True
# 7041               False         True            True              False
# 7042               False        False           False               True
#
#       Multiple Lines_No phone service  ...  Streaming TV_No internet service  \
# 0                               False  ...                             False
# 1                               False  ...                             False
# 2                               False  ...                             False
# 3                               False  ...                             False
# 4                               False  ...                             False
# ...                               ...  ...                               ...
# 7038                            False  ...                              True
# 7039                            False  ...                             False
# 7040                            False  ...                             False
# 7041                             True  ...                             False
# 7042                            False  ...                             False
#
#       Streaming TV_Yes  Streaming Movies_No internet service  \
# 0                False                                 False
# 1                False                                 False
# 2                 True                                 False
# 3                 True                                 False
# 4                 True                                 False
# ...                ...                                   ...
# 7038             False                                  True
# 7039              True                                 False
# 7040              True                                 False
# 7041             False                                 False
# 7042              True                                 False
#
#       Streaming Movies_Yes  Contract_One year  Contract_Two year  \
# 0                    False              False              False
# 1                    False              False              False
# 2                     True              False              False
# 3                     True              False              False
# 4                     True              False              False
# ...                    ...                ...                ...
# 7038                 False              False               True
# 7039                  True               True              False
# 7040                  True               True              False
# 7041                 False              False              False
# 7042                  True              False               True
#
#       Paperless Billing_Yes  Payment Method_Credit card (automatic)  \
# 0                      True                                   False
# 1                      True                                   False
# 2                      True                                   False
# 3                      True                                   False
# 4                      True                                   False
# ...                     ...                                     ...
# 7038                   True                                   False
# 7039                   True                                   False
# 7040                   True                                    True
# 7041                   True                                   False
# 7042                   True                                   False
#
#       Payment Method_Electronic check  Payment Method_Mailed check
# 0                               False                         True
# 1                                True                        False
# 2                                True                        False
# 3                                True                        False
# 4                               False                        False
# ...                               ...                          ...
# 7038                            False                        False
# 7039                            False                         True
# 7040                            False                        False
# 7041                             True                        False
# 7042                            False                        False
#
# [7032 rows x 31 columns]

# %%
X=df_encoded.drop('Churn Value',axis=1)
Y=df_encoded['Churn Value']

# %%
X.shape
# Out:
# (7032, 30)

# %%
Y.shape
# Out:
# (7032,)

# %%
print(X)
# Out:
#       Tenure Months  Monthly Charges  Total Charges  Gender_Male  \
# 0                 2            53.85         108.15         True
# 1                 2            70.70         151.65        False
# 2                 8            99.65         820.50        False
# 3                28           104.80        3046.05        False
# 4                49           103.70        5036.30         True
# ...             ...              ...            ...          ...
# 7038             72            21.15        1419.40        False
# 7039             24            84.80        1990.50         True
# 7040             72           103.20        7362.90        False
# 7041             11            29.60         346.45        False
# 7042             66           105.65        6844.50         True
#
#       Senior Citizen_Yes  Partner_Yes  Dependents_Yes  Phone Service_Yes  \
# 0                  False        False           False               True
# 1                  False        False            True               True
# 2                  False        False            True               True
# 3                  False         True            True               True
# 4                  False        False            True               True
# ...                  ...          ...             ...                ...
# 7038               False        False           False               True
# 7039               False         True            True               True
# 7040               False         True            True               True
# 7041               False         True            True              False
# 7042               False        False           False               True
#
#       Multiple Lines_No phone service  Multiple Lines_Yes  ...  \
# 0                               False               False  ...
# 1                               False               False  ...
# 2                               False                True  ...
# 3                               False                True  ...
# 4                               False                True  ...
# ...                               ...                 ...  ...
# 7038                            False               False  ...
# 7039                            False                True  ...
# 7040                            False                True  ...
# 7041                             True               False  ...
# 7042                            False               False  ...
#
#       Streaming TV_No internet service  Streaming TV_Yes  \
# 0                                False             False
# 1                                False             False
# 2                                False              True
# 3                                False              True
# 4                                False              True
# ...                                ...               ...
# 7038                              True             False
# 7039                             False              True
# 7040                             False              True
# 7041                             False             False
# 7042                             False              True
#
#       Streaming Movies_No internet service  Streaming Movies_Yes  \
# 0                                    False                 False
# 1                                    False                 False
# 2                                    False                  True
# 3                                    False                  True
# 4                                    False                  True
# ...                                    ...                   ...
# 7038                                  True                 False
# 7039                                 False                  True
# 7040                                 False                  True
# 7041                                 False                 False
# 7042                                 False                  True
#
#       Contract_One year  Contract_Two year  Paperless Billing_Yes  \
# 0                 False              False                   True
# 1                 False              False                   True
# 2                 False              False                   True
# 3                 False              False                   True
# 4                 False              False                   True
# ...                 ...                ...                    ...
# 7038              False               True                   True
# 7039               True              False                   True
# 7040               True              False                   True
# 7041              False              False                   True
# 7042              False               True                   True
#
#       Payment Method_Credit card (automatic)  Payment Method_Electronic check  \
# 0                                      False                            False
# 1                                      False                             True
# 2                                      False                             True
# 3                                      False                             True
# 4                                      False                            False
# ...                                      ...                              ...
# 7038                                   False                            False
# 7039                                   False                            False
# 7040                                    True                            False
# 7041                                   False                             True
# 7042                                   False                            False
#
#       Payment Method_Mailed check
# 0                            True
# 1                           False
# 2                           False
# 3                           False
# 4                           False
# ...                           ...
# 7038                        False
# 7039                         True
# 7040                        False
# 7041                        False
# 7042                        False
#
# [7032 rows x 30 columns]

# %%
print(Y)
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 7038    0
# 7039    0
# 7040    0
# 7041    0
# 7042    0
# Name: Churn Value, Length: 7032, dtype: int64

# %% [markdown]
# **Machine learning Implementation**

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=0.2, random_state=42)

# %%
print(X_train.shape)
# Out:
# (5625, 30)

# %%
print(X_test.shape)
# Out:
# (1407, 30)

# %%
print(Y_train.shape)
# Out:
# (5625,)

# %%
print(Y_test.shape)
# Out:
# (1407,)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model=RandomForestClassifier(n_estimators=200,random_state=42)

# %%
rf_model.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(n_estimators=200, random_state=42)

# %%
Y_pred=rf_model.predict(X_test)

# %%
Y_pred
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
print("Accuracy:",accuracy_score(Y_test,Y_pred))
# Out:
# Accuracy: 0.7931769722814499

# %%
print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.91      0.86      1012
#            1       0.68      0.51      0.58       395
#
#     accuracy                           0.79      1407
#    macro avg       0.75      0.71      0.72      1407
# weighted avg       0.78      0.79      0.78      1407

# %%
cm=confusion_matrix(Y_test,Y_pred)

# %%
print(cm)
# Out:
# [[916  96]
#  [195 200]]

# %% [markdown]
# **Approach 1-Handle class imbalance**

# %%
rf_balanced=RandomForestClassifier(n_estimators=200,random_state=42,class_weight='balanced')
rf_balanced.fit(X_train,Y_train)
y_pred_balanced=rf_balanced.predict(X_test)
accuracy_balanced=accuracy_score(Y_test,y_pred_balanced)
cm_balanced=confusion_matrix(Y_test,y_pred_balanced)
print(accuracy_balanced,cm_balanced)
print(classification_report(Y_test,y_pred_balanced))
# Out:
# 0.7960199004975125 [[923  89]
#  [198 197]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.91      0.87      1012
#            1       0.69      0.50      0.58       395
#
#     accuracy                           0.80      1407
#    macro avg       0.76      0.71      0.72      1407
# weighted avg       0.79      0.80      0.78      1407

# %% [markdown]
# **Approach 2- Hyperparameter tuning**

# %%
rf_tuned=RandomForestClassifier(n_estimators=200,random_state=42,class_weight='balanced')
rf_tuned.fit(X_train,Y_train)
y_pred_tuned=rf_tuned.predict(X_test)

print(classification_report(Y_test,y_pred_tuned))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.91      0.87      1012
#            1       0.69      0.50      0.58       395
#
#     accuracy                           0.80      1407
#    macro avg       0.76      0.71      0.72      1407
# weighted avg       0.79      0.80      0.78      1407

# %% [markdown]
# Approach 3

# %%
import pandas as pd
feature_importance=pd.DataFrame({'Features':X.columns,'Importance':rf_tuned.feature_importances_})
feature_importance=feature_importance.sort_values(by='Importance',ascending=False)
print(feature_importance)
# Out:
#                                   Features  Importance
# 2                            Total Charges    0.170950
# 0                            Tenure Months    0.166457
# 1                          Monthly Charges    0.147251
# 25                       Contract_Two year    0.057330
# 6                           Dependents_Yes    0.048356
# 10            Internet Service_Fiber optic    0.040264
# 28         Payment Method_Electronic check    0.037790
# 24                       Contract_One year    0.027998
# 13                     Online Security_Yes    0.026737
# 3                              Gender_Male    0.024133
# 26                   Paperless Billing_Yes    0.023773
# 5                              Partner_Yes    0.022962
# 19                        Tech Support_Yes    0.021134
# 15                       Online Backup_Yes    0.019753
# 4                       Senior Citizen_Yes    0.018007
# 17                   Device Protection_Yes    0.017061
# 9                       Multiple Lines_Yes    0.016798
# 23                    Streaming Movies_Yes    0.015724
# 21                        Streaming TV_Yes    0.015554
# 27  Payment Method_Credit card (automatic)    0.013662
# 29             Payment Method_Mailed check    0.012335
# 12     Online Security_No internet service    0.008244
# 18        Tech Support_No internet service    0.008121
# 16   Device Protection_No internet service    0.007732
# 22    Streaming Movies_No internet service    0.007169
# 11                     Internet Service_No    0.007060
# 20        Streaming TV_No internet service    0.005290
# 7                        Phone Service_Yes    0.004237
# 8          Multiple Lines_No phone service    0.004172
# 14       Online Backup_No internet service    0.003944

# %%
print(feature_importance.tail(15))
# Out:
#                                   Features  Importance
# 17                   Device Protection_Yes    0.017061
# 9                       Multiple Lines_Yes    0.016798
# 23                    Streaming Movies_Yes    0.015724
# 21                        Streaming TV_Yes    0.015554
# 27  Payment Method_Credit card (automatic)    0.013662
# 29             Payment Method_Mailed check    0.012335
# 12     Online Security_No internet service    0.008244
# 18        Tech Support_No internet service    0.008121
# 16   Device Protection_No internet service    0.007732
# 22    Streaming Movies_No internet service    0.007169
# 11                     Internet Service_No    0.007060
# 20        Streaming TV_No internet service    0.005290
# 7                        Phone Service_Yes    0.004237
# 8          Multiple Lines_No phone service    0.004172
# 14       Online Backup_No internet service    0.003944

# %%
X_selected=X.drop(['Phone Service_Yes','Multiple Lines_No phone service'],axis=1)

# %%
X_train_sel, X_test_sel, Y_train_sel, Y_test_sel = train_test_split(
    X_selected, Y, test_size=0.2, random_state=42)

# %%
rf_selected=RandomForestClassifier(n_estimators=200,random_state=42,max_depth=10,class_weight='balanced')
rf_selected.fit(X_train_sel,Y_train_sel)
y_pred_selected=rf_selected.predict(X_test_sel)
print(classification_report(Y_test_sel,y_pred_selected))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.84      1012
#            1       0.59      0.74      0.65       395
#
#     accuracy                           0.78      1407
#    macro avg       0.74      0.77      0.75      1407
# weighted avg       0.80      0.78      0.79      1407

# %% [markdown]
# **Approach-Combination of trees and depth**

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
from sklearn.ensemble import RandomForestClassifier
n_estimators_list=[100,200,300,400,500]
max_depth_list=[5,10,15,20]
results=[]

# Re-split X and Y to ensure X_train and Y_train have consistent sample sizes
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

for n_trees in n_estimators_list:
  for depth in max_depth_list:
    rf=RandomForestClassifier(n_estimators=n_trees,random_state=42,max_depth=depth,class_weight='balanced')
    rf.fit(X_train,Y_train)
    y_pred=rf.predict(X_test)
    accuracy=accuracy_score(Y_test,y_pred)
    recall=recall_score(Y_test,y_pred)
    precision=precision_score(Y_test,y_pred)
    f1=f1_score(Y_test,y_pred)
    results.append({'Trees':n_trees,'Depth':depth,'Accuracy':accuracy,'Recall':recall,'Precision':precision,'F1':f1})

result_df=pd.DataFrame(results)
result_df=result_df.sort_values(by=['Recall','Accuracy'],ascending=False)
print(result_df.head(20))
# Out:
#     Trees  Depth  Accuracy    Recall  Precision        F1
# 16    500      5  0.751244  0.805063   0.538071  0.645030
# 0     100      5  0.749822  0.802532   0.536379  0.643002
# 8     300      5  0.749822  0.802532   0.536379  0.643002
# 4     200      5  0.751244  0.800000   0.538330  0.643585
# 12    400      5  0.749822  0.800000   0.536503  0.642276
# 13    400     10  0.780384  0.749367   0.584980  0.657048
# 9     300     10  0.778962  0.746835   0.583004  0.654828
# 1     100     10  0.777541  0.746835   0.580709  0.653378
# 17    500     10  0.780384  0.744304   0.585657  0.655518
# 5     200     10  0.776830  0.739241   0.580517  0.650334
# 14    400     15  0.797441  0.630380   0.641753  0.636015
# 2     100     15  0.800995  0.625316   0.651715  0.638243
# 18    500     15  0.798152  0.625316   0.644909  0.634961
# 10    300     15  0.796020  0.625316   0.639896  0.632522
# 6     200     15  0.795309  0.625316   0.638243  0.631714
# 19    500     20  0.798863  0.516456   0.689189  0.590449
# 7     200     20  0.791756  0.511392   0.668874  0.579627
# 3     100     20  0.793888  0.506329   0.677966  0.579710
# 15    400     20  0.792466  0.506329   0.673401  0.578035
# 11    300     20  0.791756  0.503797   0.672297  0.575977

# %%
from sklearn.model_selection import cross_val_score
final_rf=RandomForestClassifier(n_estimators=200,random_state=42,class_weight='balanced')

# %%
cv_accuracy=cross_val_score(final_rf,X,Y,cv=5,scoring='accuracy')
print(cv_accuracy)
# Out:
# [0.77896233 0.80028429 0.7745377  0.80369844 0.79871977]

# %%
cv_accuracy.mean()
# Out:
# np.float64(0.7912405054588871)

# %%
cv_recall=cross_val_score(final_rf,X,Y,cv=5,scoring='recall')
print(cv_recall)
# Out:
# [0.43315508 0.50802139 0.48395722 0.49465241 0.50670241]

# %%
cv_recall.mean()
# Out:
# np.float64(0.4852977018250634)

# %% [markdown]
# Optional

# %%
from sklearn.metrics import roc_auc_score,roc_curve

# %%
import matplotlib.pyplot as plt

# %%
y_prob=rf_tuned.predict_proba(X)

# %%
y_prob1=rf_tuned.predict_proba(X_test)

# %%
churn_probability=y_prob[:,1]

# %%
churn_prob=y_prob1[:,1]

# %%
fpr,tpr,threshold=roc_curve(Y_test,churn_prob)
auc_score=roc_auc_score(Y_test,churn_prob)
print(auc_score)
# Out:
# 0.8406952018812228

# %% [markdown]
# **Customer Segmentation**

# %%
segmentation_data=pd.DataFrame({
    'Tenure Months':X['Tenure Months'],
    'Monthly Charges':X['Monthly Charges'],
    'Total Charges':X['Total Charges'],
    'Churn Probability':churn_probability
})

# %%
segmentation_data
# Out:
#       Tenure Months  Monthly Charges  Total Charges  Churn Probability
# 0                 2            53.85         108.15              0.800
# 1                 2            70.70         151.65              0.865
# 2                 8            99.65         820.50              0.840
# 3                28           104.80        3046.05              0.710
# 4                49           103.70        5036.30              0.680
# ...             ...              ...            ...                ...
# 7038             72            21.15        1419.40              0.000
# 7039             24            84.80        1990.50              0.025
# 7040             72           103.20        7362.90              0.000
# 7041             11            29.60         346.45              0.065
# 7042             66           105.65        6844.50              0.125
#
# [7032 rows x 4 columns]

# %% [markdown]
# **Implementation of kmeans**

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
scaled_data=scaler.fit_transform(segmentation_data)
print(scaled_data[:5])
# Out:
# [[-1.23950408 -0.36392329 -0.95964911  1.63623372]
#  [-1.23950408  0.19617818 -0.94045745  1.83472056]
#  [-0.99504031  1.15848901 -0.64536922  1.75837947]
#  [-0.18016108  1.3296773   0.33651554  1.36140577]
#  [ 0.6754621   1.29311281  1.2145889   1.26979646]]

# %%
from sklearn.cluster import KMeans
import numpy as np # Ensure numpy is imported for nanmedian and nan_to_num

wcss=[]

for k in range(1,16):
    kmeans = KMeans(
        n_clusters=k,
        random_state=42,
        n_init=10
    )
    kmeans.fit(scaled_data)
    wcss.append(kmeans.inertia_)

# Plotting the Elbow Method results after the loop
plt.figure(figsize=(8,6))
plt.plot(range(1,16),wcss,marker='o')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.title('Elbow Method For Optimal k') # Added title for clarity
plt.show()

# %%
 kmeans=KMeans(n_clusters=4,random_state=42,n_init=10)

# %%
clusters=kmeans.fit_predict(scaled_data)

# %%
segmentation_data['Cluster']=clusters

# %%
segmentation_data
# Out:
#       Tenure Months  Monthly Charges  Total Charges  Churn Probability  \
# 0                 2            53.85         108.15              0.800
# 1                 2            70.70         151.65              0.865
# 2                 8            99.65         820.50              0.840
# 3                28           104.80        3046.05              0.710
# 4                49           103.70        5036.30              0.680
# ...             ...              ...            ...                ...
# 7038             72            21.15        1419.40              0.000
# 7039             24            84.80        1990.50              0.025
# 7040             72           103.20        7362.90              0.000
# 7041             11            29.60         346.45              0.065
# 7042             66           105.65        6844.50              0.125
#
#       Cluster
# 0           2
# 1           2
# 2           2
# 3           2
# 4           0
# ...       ...
# 7038        3
# 7039        1
# 7040        0
# 7041        1
# 7042        0
#
# [7032 rows x 5 columns]

# %%
cluster_summary=segmentation_data.groupby('Cluster').mean()

# %%
cluster_summary
# Out:
#          Tenure Months  Monthly Charges  Total Charges  Churn Probability
# Cluster
# 0            58.212787        92.871354    5402.347478           0.134785
# 1            13.608969        49.722534     734.306704           0.117287
# 2            11.950980        73.442188     958.875490           0.792104
# 3            52.736301        33.384974    1745.102997           0.028716

# %%
cluster_names = {
    0: 'Loyal Premium Customers',
    1: 'New Regular Customers',
    2: 'High Risk Customers',
    3: 'Stable Long-Term Customers'
}

# %%
segmentation_data['Cluster Segment']=segmentation_data['Cluster'].map(cluster_names)

# %%
segmentation_data[['Cluster','Cluster Segment']].head(20)
# Out:
#     Cluster          Cluster Segment
# 0         2      High Risk Customers
# 1         2      High Risk Customers
# 2         2      High Risk Customers
# 3         2      High Risk Customers
# 4         0  Loyal Premium Customers
# 5         2      High Risk Customers
# 6         2      High Risk Customers
# 7         2      High Risk Customers
# 8         0  Loyal Premium Customers
# 9         2      High Risk Customers
# 10        2      High Risk Customers
# 11        2      High Risk Customers
# 12        2      High Risk Customers
# 13        2      High Risk Customers
# 14        2      High Risk Customers
# 15        1    New Regular Customers
# 16        2      High Risk Customers
# 17        1    New Regular Customers
# 18        2      High Risk Customers
# 19        2      High Risk Customers

# %%
segmentation_data
# Out:
#       Tenure Months  Monthly Charges  Total Charges  Churn Probability  \
# 0                 2            53.85         108.15              0.800
# 1                 2            70.70         151.65              0.865
# 2                 8            99.65         820.50              0.840
# 3                28           104.80        3046.05              0.710
# 4                49           103.70        5036.30              0.680
# ...             ...              ...            ...                ...
# 7038             72            21.15        1419.40              0.000
# 7039             24            84.80        1990.50              0.025
# 7040             72           103.20        7362.90              0.000
# 7041             11            29.60         346.45              0.065
# 7042             66           105.65        6844.50              0.125
#
#       Cluster             Cluster Segment
# 0           2         High Risk Customers
# 1           2         High Risk Customers
# 2           2         High Risk Customers
# 3           2         High Risk Customers
# 4           0     Loyal Premium Customers
# ...       ...                         ...
# 7038        3  Stable Long-Term Customers
# 7039        1       New Regular Customers
# 7040        0     Loyal Premium Customers
# 7041        1       New Regular Customers
# 7042        0     Loyal Premium Customers
#
# [7032 rows x 6 columns]

# %%
plt.figure(figsize=(10,8))

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='Monthly Charges',y='Churn Probability',hue='Cluster Segment',data=segmentation_data,palette='Spectral')
plt.title('Monthly Charges vs Churn Probability')
plt.xlabel('Monthly Charges')
plt.legend(bbox_to_anchor=(1.05,1), loc='upper left')
plt.ylabel('Churn Probability')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='Tenure Months',y='Churn Probability',hue='Cluster Segment',data=segmentation_data,palette='Spectral')
plt.title('Tenure Months vs Churn Probability')
plt.legend(bbox_to_anchor=(1.05,1), loc='upper left')
plt.xlabel('Tenure Months')
plt.ylabel('Churn Probability')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='Total Charges',y='Churn Probability',hue='Cluster Segment',data=segmentation_data,palette='Spectral')
plt.title('Total Charges vs Churn Probability')
plt.legend(bbox_to_anchor=(1.05,1), loc='upper left')
plt.xlabel('Total Charges')
plt.ylabel('Churn Probability')
plt.show()

# %% [markdown]
# **Customer Segment Summary Table**

# %%
segment_summary = segmentation_data.groupby('Cluster Segment').agg({
    'Tenure Months':'mean',
    'Monthly Charges':'mean',
    'Total Charges':'mean',
    'Churn Probability':'mean'
}).round(2)

print(segment_summary)
# Out:
#                             Tenure Months  Monthly Charges  Total Charges  \
# Cluster Segment
# High Risk Customers                 11.95            73.44         958.88
# Loyal Premium Customers             58.21            92.87        5402.35
# New Regular Customers               13.61            49.72         734.31
# Stable Long-Term Customers          52.74            33.38        1745.10
#
#                             Churn Probability
# Cluster Segment
# High Risk Customers                      0.79
# Loyal Premium Customers                  0.13
# New Regular Customers                    0.12
# Stable Long-Term Customers               0.03

# %% [markdown]
# **Business Importance of Segmentation:**

# %% [markdown]
# Customer segmentation enables companies to identify different groups of customers based on their behavior and churn risk. This helps businesses implement targeted retention strategies, improve customer satisfaction, and maximize revenue.

# %% [markdown]
# **Project Limitations:**

# %% [markdown]
# 1. The model performance depends on the quality of the dataset.
# 2. Results may vary for datasets from different industries.
# 3. Customer behavior can change over time, requiring periodic model retraining.
# 4. Clustering results depend on the selected features and number of clusters.

# %% [markdown]
# **Final Conclusion:**

# %% [markdown]
# This project successfully developed a customer churn prediction and segmentation system using machine learning techniques. Random Forest achieved approximately 79% accuracy in predicting customer churn. K-Means clustering divided customers into meaningful groups such as High Risk Customers, Loyal Premium Customers, New Regular Customers, and Stable Long-Term Customers. The generated insights can help organizations improve customer retention and make data-driven business decisions.
